# %% [markdown]
# # Tutorial 01: Cumulative Distribution Transform (CDT)
#
# This tutorial will demonstrate: how to use the forward and inverse operations of the CDT in the *optimaltransport* Python package. We will cover the following transforms:
# * Forward and inverse operations of the CDT
# * CDT Properties - translation, scaling, and linear separability in CDT space

# %%
import numpy as np

import matplotlib.pyplot as plt
from matplotlib import colors
from matplotlib import rcParams
rcParams.update({'font.size': 12})

# %% [markdown]
# Create reference $I_0$ (uniform distribution) and a demo signal $I_1$

# %%
N=250
I0= np.ones(N)
x=np.arange(N)
mu=100
sigma=10
I1=1/(sigma*np.sqrt(2*np.pi))*np.exp(-((x-mu)**2)/(2*sigma**2))

# %% [markdown]
# Convert signals to strictly positive PDFs

# %%
epsilon = 1e-7
I0 = I0 + epsilon
I0 = abs(I0)/I0.sum()
I1 = I1 + epsilon
I1 = abs(I1)/I1.sum()

# %% [markdown]
# # Forward CDT

# %%
from optrans.continuous.cdt import CDT

# Create a CDT object
cdt = CDT()

# Compute the forward transform
I1_hat, f1_hat = cdt.forward(I0, I1, rm_edge=False)

# Plot I1 and I1_hat
fontSize=14
fig, ax = plt.subplots(1, 3, sharex=False, sharey=False)
ax[0].plot(x,I1, 'r-',linewidth=2)
ax[0].set_title('Original signal (I1)',fontsize=fontSize)
ax[0].set_xticks([])

ax[1].plot(I1_hat, 'b-',linewidth=2)
ax[1].set_title('CDT of I1',fontsize=fontSize)
ax[1].set_xticks([])

ax[2].plot(f1_hat, 'g-',linewidth=2)
ax[2].set_title('Transport map',fontsize=fontSize)
ax[2].set_xticks([])

fig.tight_layout()

plt.show()

# %% [markdown]
# # Inverse CDT
# Reconstruct the original signal $I_1$ from $\hat{I_1}$ using inverse CDT

# %%
I1_recon = cdt.inverse()

fig, ax = plt.subplots(1, 2, sharex=True, sharey=True)
ax[0].plot(I1_recon, 'b-')
ax[0].set_title('Reconstructed signal (I1_recon)')
ax[0].set_xticks([])

ax[1].plot(I1, 'r-')
ax[1].set_title('Original signal (I1)')
fig.tight_layout()
plt.show()

# %% [markdown]
# # Translation
# Generate a second signal $I_2$ which is a shifted version $I_1$

# %%
from scipy.ndimage.interpolation import shift
D = 50
I1=1/(sigma*np.sqrt(2*np.pi))*np.exp(-((x-mu)**2)/(2*sigma**2))
I2 = shift(I1,D)

fig, ax = plt.subplots(1, 2, sharex=True, sharey=True)
ax[0].plot(I1, 'b-')
ax[0].plot(I2, 'r-')
ax[0].set_title('Reconstructed signal (I1_recon)')
ax[0].set_xticks([])

ax[1].plot(I1, 'b-')
ax[1].plot(I2, 'r-')
ax[1].set_title('Original signal (I1)')
fig.tight_layout()
plt.show()
